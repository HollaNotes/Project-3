# %%
# Import SQLAlchemy `automap` and other dependencies 10.2.5
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, text
from pathlib import Path
import pandas as pd
from sqlalchemy import Column, Integer, String, Float
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import create_engine, MetaData, Table, Column, ForeignKey
from sqlalchemy.ext.automap import automap_base

# %%
# Create the connection engine
engine = create_engine("postgresql://postgres:password@localhost:5432/Project 3")
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['filter6', 'realestateca', 'realestateca2']

# %%
Base = automap_base()
engine = create_engine("postgresql://postgres:password@localhost:5432/Project 3")



session = Session(engine)

# %%
inspector.get_columns('filter6')
# Out:
# [{'name': 'temp_index',
#   'type': VARCHAR(),
#   'nullable': False,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'id',
#   'type': VARCHAR(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'stateid',
#   'type': NUMERIC(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'countyid',
#   'type': NUMERIC(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'cityid',
#   'type': NUMERIC(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'country',
#   'type': VARCHAR(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'datepostedstring',
#   'type': VARCHAR(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'is_bankowned',
#   'type': VARCHAR(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'is_forauction',
#   'type': VARCHAR(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'event',
#   'type': VARCHAR(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'time',
#   'type': NUMERIC(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'price',
#   'type': NUMERIC(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'pricepersquarefoot',
#   'type': NUMERIC(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'city',
#   'type': VARCHAR(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'state',
#   'type': VARCHAR(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'yearbuilt',
#   'type': NUMERIC(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'streetaddress',
#   'type': VARCHAR(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'zipcode',
#   'type': NUMERIC(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'longitude',
#   'type': NUMERIC(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'latitude',
#   'type': NUMERIC(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'hasbadgeocode',
#   'type': VARCHAR(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'description',
#   'type': TEXT(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'currency',
#   'type': VARCHAR(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'livingarea',
#   'type': NUMERIC(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'livingareavalue',
#   'type': NUMERIC(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'lotareaunits',
#   'type': VARCHAR(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'bathrooms',
#   'type': NUMERIC(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'bedrooms',
#   'type': NUMERIC(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'buildingarea',
#   'type': NUMERIC(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'parking',
#   'type': VARCHAR(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'garagespaces',
#   'type': NUMERIC(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'hasgarage',
#   'type': VARCHAR(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'levels',
#   'type': VARCHAR(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'pool',
#   'type': VARCHAR(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'spa',
#   'type': VARCHAR(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'isnewconstruction',
#   'type': VARCHAR(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'haspetsallowed',
#   'type': VARCHAR(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'hometype',
#   'type': VARCHAR(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'county',
#   'type': VARCHAR(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None}]

# %%
conn = engine.connect()

# %%
# Query All Records in the the Database
data = pd.read_sql("SELECT * FROM filter6", conn)

# Preview the Data
data.head()
# Out:
#   temp_index              id  stateid  countyid   cityid country  \
# 0          2  94564-18496265      9.0     189.0  36958.0     USA
# 1          3  94564-18484475      9.0     190.0  36958.0     USA
# 2          4  94564-18494835      9.0     191.0  36958.0     USA
# 3          6  94564-18484390      9.0     193.0  36958.0     USA
# 4          7  94564-50919342      9.0     194.0  36958.0     USA
#
#   datepostedstring is_bankowned is_forauction            event  ...  parking  \
# 0        7/12/2021            0             0  Listed for sale  ...        1
# 1         7/8/2021            0             0  Listed for sale  ...        1
# 2         7/7/2021            0             0  Listed for sale  ...        1
# 3         7/6/2021            0             0  Listed for sale  ...        1
# 4         7/5/2021            0             0  Listed for sale  ...        1
#
#    garagespaces  hasgarage     levels pool  spa isnewconstruction  \
# 0           2.0          1  One Story    0    0                 0
# 1           2.0          1  One Story    0    0                 0
# 2           1.0          1  Two Story    0    1                 0
# 3           2.0          1  One Story    0    0                 0
# 4           2.0          1  Two Story    0    0                 0
#
#    haspetsallowed       hometype               county
# 0               0  SINGLE_FAMILY  Contra Costa County
# 1               0  SINGLE_FAMILY  Contra Costa County
# 2               0  SINGLE_FAMILY  Contra Costa County
# 3               0  SINGLE_FAMILY  Contra Costa County
# 4               0  SINGLE_FAMILY  Contra Costa County
#
# [5 rows x 39 columns]

# %%
# Reflect Database into ORM classes
Base = automap_base()
Base.prepare(autoload_with=engine)
Base.classes.keys()
# Out:
# ['filter6', 'realestateca2']
