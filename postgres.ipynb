# %%
# Import SQLAlchemy `automap` and other dependencies 10.2.5
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, text
from pathlib import Path
import pandas as pd
from sqlalchemy import Column, Integer, String, Float
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy import create_engine, MetaData, Table, Column, ForeignKey
from sqlalchemy.ext.automap import automap_base

# %%
# Create the connection engine
engine = create_engine("postgresql://postgres:password@localhost:5432/Project 3")
inspector = inspect(engine)
inspector.get_table_names()
# Out:
# ['realestateca', 'realestateca2']

# %%
m = MetaData()
b = automap_base(bind=engine, metadata=m)
b.prepare(engine, reflect=True)
b.classes.keys()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 m = MetaData()
# ----> 2 b = automap_base(bind=engine, metadata=m)
#       3 b.prepare(engine, reflect=True)
#       4 b.classes.keys()
#
# File c:\Users\noell\anaconda3\Lib\site-packages\sqlalchemy\ext\automap.py:1401, in automap_base(declarative_base, **kw)
#    1381 r"""Produce a declarative automap base.
#    1382
#    1383 This function produces a new base class that is a product of the
#    (...)
#    1398
#    1399 """
#    1400 if declarative_base is None:
# -> 1401     Base = _declarative_base(**kw)
#    1402 else:
#    1403     Base = declarative_base
#
# TypeError: declarative_base() got an unexpected keyword argument 'bind'

# %%
Base = automap_base()
engine = create_engine("postgresql://postgres:password@localhost:5432/Project 3")



session = Session(engine)

# %%
inspector.get_columns('realestateca2')
# Out:
# [{'name': 'temp_index',
#   'type': VARCHAR(),
#   'nullable': False,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'id',
#   'type': VARCHAR(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'stateid',
#   'type': NUMERIC(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'countyid',
#   'type': NUMERIC(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'cityid',
#   'type': NUMERIC(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'country',
#   'type': VARCHAR(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
#  {'name': 'datepostedstring',
#   'type': DATE(),
#   'nullable': True,
#   'default': None,
#   'autoincrement': False,
#   'comment': None},
# ...

# %%
conn = engine.connect()

# %%
# Query All Records in the the Database
data = pd.read_sql("SELECT * FROM realestateca", conn)

# Preview the Data
data.head()
# Out:
#                id  stateid  countyid   cityid country datepostedstring  \
# 0  94564-18496265      9.0     189.0  36958.0     USA       2021-07-12
# 1  94564-18484475      9.0     190.0  36958.0     USA       2021-07-08
# 2  94564-18494835      9.0     191.0  36958.0     USA       2021-07-07
# 3  94564-18484390      9.0     193.0  36958.0     USA       2021-07-06
# 4  94564-50919342      9.0     194.0  36958.0     USA       2021-07-05
#
#    is_bankowned  is_forauction            event          time  ...  parking  \
# 0         False          False  Listed for sale  1.630000e+12  ...     True
# 1         False          False  Listed for sale  1.630000e+12  ...     True
# 2         False          False  Listed for sale  1.630000e+12  ...     True
# 3         False          False  Listed for sale  1.630000e+12  ...     True
# 4         False          False  Listed for sale  1.630000e+12  ...     True
#
#    garagespaces hasgarage     levels   pool    spa  isnewconstruction  \
# ...

# %%
# Reflect Database into ORM classes
Base = automap_base()
Base.prepare(autoload_with=engine)
Base.classes.keys()
# Out:
# ['realestateca2']
